# %% [markdown]
# # Computer Assignment 5 Phase 1
# # Feed Forward Neural Network
# ## Ali Bahari
#
# Project Name: Computer Assignment 5 Phase 1 Feed Forward Neural Network
#
# Project Goal: Implement a feed forward neural network for image classification then train the model with the provided images in the train dataset and finally test the model using the provided images in the test dataset.
#
# In this assignment we're going to implement a feed forward neural network which will be used for image classification. Train and test datasets are provided and in each of them there are many 28 by 28 images which are represented by 784 numbers between 0 to 255 which corresponds to each pixel's brightness. First we start by preprocessing the dataset, taking a look at some of the images to understand how the dataset looks like, and we'll do some modifications to make the dataset ready for being sent to the neural network. For implementing the neural network, required explanation is provided at each step further down the report. Finally after implementation training the model and tuning the hyperparameters are done and the model is tested using the preprocessed test dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
train_dataset = pd.read_csv("./dataset/train_images.csv")
train_labels = pd.read_csv("./dataset/train_labels.csv")

# %%
image = np.array(train_dataset.iloc[random.randint(0 , len(train_dataset) - 1) , 1:]).reshape(28 , 28)

plt.figure(figsize = (2 , 2))
plt.imshow(image)
plt.title("Random Image From Train Dataset")
plt.show()

plt.figure(figsize = (2 , 2))
plt.imshow(image , cmap = "gray")
plt.title("Random Gray Image From Train Dataset")
plt.show()

print("==========================")

print("Minimum value in image: " + str(np.amin(image)))
print("Maximum value in image: " + str(np.amax(image)))
# Out:
# ==========================
# Minimum value in image: 0
# Maximum value in image: 255

# %% [markdown]
# As shown above image values in the dataset which represent the brightness of each pixel is a number between 0 to 255.

# %%
for classNumber in range(20):
    imageRowNum = train_labels[train_labels.iloc[: , 1] == classNumber].iloc[0 , 0]
    image = np.array(train_dataset.iloc[imageRowNum , 1:]).reshape(28 , 28)
    
    print("=============== CLASS " + str(classNumber) + " ===============")
    
    plt.figure(figsize = (2 , 2))
    plt.imshow(image)
    plt.title("Class " + str(classNumber))
    plt.show()
    
    plt.figure(figsize = (2 , 2))
    plt.imshow(image , cmap = "gray")
    plt.title("Class " + str(classNumber) + " Gray")
    plt.show()
# Out:
# =============== CLASS 0 ===============
# =============== CLASS 1 ===============
# =============== CLASS 2 ===============
# =============== CLASS 3 ===============
# =============== CLASS 4 ===============
# =============== CLASS 5 ===============
# =============== CLASS 6 ===============
# =============== CLASS 7 ===============
# =============== CLASS 8 ===============
# =============== CLASS 9 ===============
# =============== CLASS 10 ===============
# =============== CLASS 11 ===============
# =============== CLASS 12 ===============
# =============== CLASS 13 ===============
# =============== CLASS 14 ===============
# =============== CLASS 15 ===============
# =============== CLASS 16 ===============
# =============== CLASS 17 ===============
# =============== CLASS 18 ===============
# =============== CLASS 19 ===============

# %%
train_labels.iloc[: , 1].value_counts().sort_index().plot(kind = "bar", title = "Number of Images Per Class Train Dataset");

# %%
train_dataset_matrix = train_dataset.iloc[: , 1:].to_numpy()
train_labels_matrix = train_labels.iloc[: , 1].to_numpy()

train_dataset_matrix = train_dataset_matrix / 255

# %% [markdown]
# Since maximum value in the dataset is 255 it's a good idea to divide every value in the dataset by 255, this will result in each value being between 0 to 1. The reason that this procedure is done is that higher numbers in the network will make it biased meaning that since the difference between values in the range of 0 to 255 is a lot the effect of a value like 1 can easily be vanished comapred to 255 so it's a wise move to scale the values down to make each of them have somewhat of a equal impact in the network. Biased network can result in lower accuracy and all in all a poor model.

# %% [markdown]
# # Dataloader

# %%
class Dataloader:
    
    def __init__(self, data, labels, n_classes, batch_size=None, shuffle=False):

        assert len(data)==len(labels)
        self.__n_classes = n_classes
        self.__batch_size = batch_size
        self.__shuffle = shuffle
        self.__data = data
        self.__onehot_labels = self.__onehot(labels, self.__n_classes)
    
    def __onehot(self, labels, n_classes):
        matrix = []
        for label in labels:
            row = []
            for numClass in range(n_classes):
                if(numClass == label):
                    row.append(1)
                else:
                    row.append(0)
            
            matrix.append(row)
        
        return np.matrix(matrix , copy = False)
    
    def __shuffle_dataset(self):
        randomIndices = np.random.permutation(len(self.__data))
        self.__data = self.__data[randomIndices]
        self.__onehot_labels = self.__onehot_labels[randomIndices]
    
    def __iter__(self):
        
        if self.__shuffle:
            self.__shuffle_dataset()
            
        if self.__batch_size==None:
            yield (np.matrix(self.__data), np.matrix(self.__onehot_labels))
            return
            
        for idx in range(0, len(self.__data), self.__batch_size):
            yield (np.matrix(self.__data[idx:idx+self.__batch_size]), 
                   np.matrix(self.__onehot_labels[idx:idx+self.__batch_size]))

# %% [markdown]
# The codes for one hot and shuffle are pretty straight forward.

# %% [markdown]
# # Activation Functions

# %%
class Identical:
    
    def __init__(self): pass
    
    def __val(self, matrix):
        identical_value = np.matrix(matrix, dtype=float)
        return identical_value

    def derivative(self, matrix):
        temp = np.matrix(matrix, dtype=float)
        identical_derivative = np.matrix(np.full(np.shape(temp), 1.))
        return identical_derivative
    
    def __call__(self, matrix):
        return self.__val(matrix)
    

class Relu:
    
    def __init__(self): pass
    
    def __val(self, matrix):
        return np.maximum(0 , matrix)

    def derivative(self, matrix):
        derivativeReluMatrix = np.matrix(matrix)
        derivativeReluMatrix[matrix < 0] = 0; derivativeReluMatrix[matrix >= 0] = 1
        return derivativeReluMatrix
    
    def __call__(self, matrix):
        return self.__val(matrix)

    
class LeakyRelu:
    
    def __init__(self, negative_slope=0.01):
        self.negative_slope = 0.01
    
    def __val(self, matrix):
        leakyReluMatrix = np.matrix(matrix)
        leakyReluMatrix = np.where(leakyReluMatrix < 0, self.negative_slope * leakyReluMatrix , leakyReluMatrix)
        return leakyReluMatrix

    def derivative(self, matrix):
        derivativeLeakyReluMatrix = np.matrix(matrix)
        derivativeLeakyReluMatrix = np.where(derivativeLeakyReluMatrix < 0 , self.negative_slope , 1)
        return derivativeLeakyReluMatrix
    
    def __call__(self, matrix):
        return self.__val(matrix)

    
class Sigmoid:
    
    def __init__(self): pass

    def __val(self, matrix):
        return np.matrix(1 / (1 + np.exp(-matrix)))

    def derivative(self, matrix):
        return np.multiply(self.__val(matrix) , np.matrix(1 - self.__val(matrix)))
    
    def __call__(self, matrix):
        return self.__val(matrix)


class Softmax:
    
    def __init__(self): pass

    def __val(self, matrix):
        # Stable Softmax hence the subtraction
        # Axis 1 means horizontal
        stableSoftmaxMatrix = np.matrix(matrix)
        stableSoftmaxMatrix = stableSoftmaxMatrix - stableSoftmaxMatrix.max(axis = 1)
        return np.matrix(np.exp(stableSoftmaxMatrix) / np.exp(stableSoftmaxMatrix).sum(axis = 1))
    
    def __call__(self, matrix):
        return self.__val(matrix)
    
class Tanh:
    
    def __init__(self): pass

    def __val(self, matrix):
        return np.matrix((np.exp(matrix) - np.exp(-matrix)) / (np.exp(matrix) + np.exp(-matrix)))

    def derivative(self, matrix):
        return 1 - np.power(self.__val(matrix) , 2)
    
    def __call__(self, matrix):
        return self.__val(matrix)

# %% [markdown]
# # Loss Function

# %%
class CrossEntropy: #(with softmax)
    
    def __init__(self): pass

    def __val(self, true_val, expected_val):
        assert np.shape(true_val)==np.shape(expected_val)
        
        cross_entropy_value = -np.multiply(expected_val , np.log(Softmax()(true_val) )).sum(axis = 1) 
        return cross_entropy_value
        
    def derivative(self, true_val, expected_val):
        assert np.shape(true_val)==np.shape(expected_val)
        return Softmax()(true_val) - expected_val
    
    def __call__(self, true_val, expected_val):
        return self.__val(true_val, expected_val)

# %% [markdown]
# # Layer

# %%
class Layer:

    DEFAULT_LOW, DEFAULT_HIGH, DEFAULT_MEAN, DEFAULT_VAR = 0, 0.05, 0., 1.
  
    def __init__(self, input_size, output_size, 
                 activation=Identical(), initial_weight='uniform', **initializing_parameters):
        
        assert type(initial_weight)==str, 'Undefined activation function!'
        
        self.__weight_initializer_dict = {'uniform':self.__uniform_weight, 'normal':self.__normal_weight}
        
        assert initial_weight in self.__weight_initializer_dict, 'Undefined weight initialization function!'


        self.__n_neurons = output_size
        weight_initializer = self.__weight_initializer_dict[initial_weight]
        self.__weight = weight_initializer(input_size, self.__n_neurons, **initializing_parameters)
        self.__bias = weight_initializer(1, self.__n_neurons, **initializing_parameters)
        self.__activation = activation
        
        self.__last_input = None
        self.__last_activation_input = None
        self.__last_activation_output = None
        self.__last_activation_derivative = None
        
    def forward(self, layer_input):
        assert np.ndim(layer_input)==2
        assert np.size(self.__weight,0) == np.size(layer_input,1)
        
        self.__last_input = layer_input
        self.__last_activation_input = np.matmul(layer_input , self.__weight) + self.__bias
        self.__last_activation_output = self.__activation(self.__last_activation_input)
        self.__last_activation_derivative = self.__activation.derivative(self.__last_activation_input)
        
        return self.__last_activation_output
    
    def update_weights(self, backprop_tensor, lr):
        assert np.ndim(backprop_tensor)==2
        assert np.size(backprop_tensor,0) == np.size(self.__last_activation_derivative,0)
        assert np.size(backprop_tensor,1) == self.__n_neurons
        
        weightsTransposed = self.__weight.transpose()
        inputsTransposed = self.__last_input.transpose()
        
        deltaCurrent = np.multiply(backprop_tensor , self.__last_activation_derivative)
        
        weightsDerivative = np.matmul(inputsTransposed , deltaCurrent)
        biasDerivative = np.matmul(np.ones(deltaCurrent.shape[0]) , deltaCurrent)
        
        self.__weight = self.__weight - lr * weightsDerivative
        self.__bias = self.__bias - lr * biasDerivative
        
        backprop_tensor = np.matmul(deltaCurrent , weightsTransposed)
        
        return backprop_tensor

    def __uniform_weight(self, dim1, dim2, **initializing_parameters):
        low, high = self.DEFAULT_LOW, self.DEFAULT_HIGH
        if 'low' in initializing_parameters.keys(): low = initializing_parameters['low']
        if 'high' in initializing_parameters.keys(): high = initializing_parameters['high']
        
        randomUniformWeights = np.random.uniform(low , high , size = (dim1 , dim2))        
        return np.matrix(randomUniformWeights)

    def __normal_weight(self, dim1, dim2, **initializing_parameters):
        mean, var = self.DEFAULT_MEAN, self.DEFAULT_VAR
        if 'mean' in initializing_parameters.keys(): mean = initializing_parameters['mean']
        if 'var' in initializing_parameters.keys(): var = initializing_parameters['var']
        
        randomNormalWeights = np.random.normal(mean , var ** 0.5 , size = (dim1 , dim2))
        return np.matrix(randomNormalWeights)
    
    def getLastActivationOutput(self):
        return self.__last_activation_output
    
    @property
    def n_neurons(self): return self.__n_neurons
    
    @property
    def weight(self): return self.__weight
    
    @property
    def bias(self): return self.__bias
    
    @property
    def activation(self): return self.__activation

# %% [markdown]
# #### Importent Note!!!
#
# In layer, all TODO methods were pretty straight forward bu update_weights method was challenging and really hard to visualize and code so to make the steps taken above to code update_weights more clear there's a provided picture in delivered files named "update_weights Thought Process.jpg" which shows the calculations that I've done on paper and the also the steps that I've taken. It's kinda messy but I thought It's worth it to show the thought process that went behind coding update_weights.

# %% [markdown]
# # Feed Forward Neural Network

# %%
class FeedForwardNN:
    
    def __init__(self, input_shape):
        
        self.__input_shape = input_shape
        self.__output_shape = None
        
        self.__layers_list = []
        
        self.__lr = None
        self.__loss = None

        
    def add_layer(self, n_neurons, activation=Relu(), initial_weight='uniform', **initializing_parameters):
         
        assert type(n_neurons)==int, "Invalid number of neurons for the layer!"
        assert n_neurons>0, "Invalid number of neurons for the layer!"
        
        n_prev_neurons = self.__input_shape if len(self.__layers_list)==0 else self.__layers_list[-1].n_neurons
        new_layer = Layer(n_prev_neurons, n_neurons, activation, initial_weight, **initializing_parameters)
        self.__layers_list.append(new_layer)
        self.__output_shape = self.__layers_list[-1].n_neurons 
      
    
    def set_training_param(self, loss=CrossEntropy(), lr=1e-3):
        assert self.__layers_list, "Uncomplete model!"
        self.__loss = loss
        self.__lr = lr
    
    
    def forward(self, network_input):
        assert type(self.__output_shape) != None, "Model is not compiled!"
        
        network_output = network_input
        for layer in self.__layers_list:
            network_output = layer.forward(network_output)
        
        return network_output
    
    
    def fit(self, epochs, trainloader, testloader=None, print_results=True):
        
        assert type(self.__output_shape) != None, "Model is not compiled!"
        assert type(self.__lr) != None and type(self.__loss) != None, "Training paramenters are not set!"

        log = {"train_accuracy":[], "train_loss":[], "test_accuracy":[], "test_loss":[]}
        
        for epoch in range(1, epochs+1):
            
            if print_results: 
                print('Epoch {}:'.format(epoch)) 
                
            average_accuracy, average_loss = self.__train(trainloader)
            log['train_accuracy'].append(average_accuracy)
            log['train_loss'].append(average_loss)
            if print_results:
                print('\tTrain: Average Accuracy: {}\tAverage Loss: {}'.format(average_accuracy, average_loss))
            
            if type(testloader) != type(None):
                average_accuracy, average_loss = self.__test(testloader)
                log['test_accuracy'].append(average_accuracy)
                log['test_loss'].append(average_loss)
                if print_results:
                    print('\tTest: Average Accuracy: {}\tAverage Loss: {}'.format(average_accuracy, average_loss))
                    
        return log
    
    
    def __train(self, trainloader):
        bach_accuracies, batch_losses = [], []
        for x_train, y_train in trainloader:
            batch_accuracy, batch_loss = self.__train_on_batch(x_train, y_train)
            bach_accuracies.append(batch_accuracy)
            batch_losses.append(batch_loss)
        return np.mean(bach_accuracies), np.mean(batch_losses)
    
    
    def __test(self, testloader):
        bach_accuracies, batch_losses = [], []
        for x_test, y_test in testloader:
            batch_accuracy, batch_loss = self.__test_on_batch(x_test, y_test)
            bach_accuracies.append(batch_accuracy)
            batch_losses.append(batch_loss)
        return np.mean(bach_accuracies), np.mean(batch_losses)

    
    def __train_on_batch(self, x_batch, y_batch):
        forwardResult = self.forward(x_batch)
        batch_accuracy = self.__compute_accuracy(forwardResult , y_batch)
        batch_average_loss = self.__update_weights(forwardResult , y_batch)
        
        return (batch_accuracy, batch_average_loss)
        
        
    def __test_on_batch(self, x_batch, y_batch):
        forwardResult = self.forward(x_batch)
        batch_accuracy = self.__compute_accuracy(forwardResult , y_batch)
        batch_average_loss = np.sum(CrossEntropy()(forwardResult , y_batch)) / len(forwardResult)
        
        return (batch_accuracy, batch_average_loss)
            
        
    def __get_labels(self, outputs):
        return outputs.argmax(axis = 1)
    
    
    def __compute_accuracy(self, output, expected_output):
        corrects = np.sum(np.argmax(output , axis = 1) == np.argmax(expected_output , axis = 1))
        return (corrects / len(np.argmax(output , axis = 1))) * 100
    
    
    def __update_weights(self, output, y_train):
        crossEntropy = CrossEntropy()
        derivativeCE = crossEntropy.derivative(output , y_train)
        for layer in self.__layers_list[::-1]:
            derivativeCE = layer.update_weights(derivativeCE , self.__lr)
        
        return np.sum(crossEntropy(output , y_train)) / len(output)

# %% [markdown]
# Since here we're doing the network processes some methods are done in a recursive like manner but no worries they're pretty straight forward as well.

# %% [markdown]
# # Training Sample Code

# %%
test_dataset = pd.read_csv("./dataset/test_images.csv")
test_labels = pd.read_csv("./dataset/test_labels.csv")

# %%
test_dataset_matrix = test_dataset.iloc[: , 1:].to_numpy()
test_labels_matrix = test_labels.iloc[: , 1].to_numpy()

test_dataset_matrix = test_dataset_matrix / 255

# %%
test_labels.iloc[: , 1].value_counts().sort_index().plot(kind = "bar" , title = "Number of Images Per Class Test Dataset");

# %% [markdown]
# After loading test set and doing the same preprocesses as before we're ready to test our model.
#
# #### Network Architecture
#
# The neural network that I implemented consists of 1 input layer, 1 hidden layer and 1 output layer. 784 input nodes, 30 hidden nodes and 20 output nodes corresponding to 20 labels that we have.
#
# I have tried higher number of hidden nodes and it'll result in higher accuracy I even reached 83 percent accuracy on test set with 100 nodes in hidden layer but at the end for getting the results faster I set 30 nodes for hidden layer but I can't say this enough feel absolutely free to raise the number of hidden nodes to get higher accuracy.

# %%
def generateTrainLoader(train_dataset_matrix , train_labels_matrix , numClasses , batchSize):
    TRAINLOADER = []
    trainLoader = Dataloader(train_dataset_matrix , train_labels_matrix , numClasses , batchSize , True)
    for data in trainLoader:
        TRAINLOADER.append(data)
        
    return TRAINLOADER


def generateTestLoader(test_dataset_matrix , test_labels_matrix , numClasses , batchSize):
    TESTLOADER = []
    testLoader = Dataloader(test_dataset_matrix , test_labels_matrix , numClasses , batchSize , True)
    for data in testLoader:
        TESTLOADER.append(data)
        
    return TESTLOADER

# %% [markdown]
# If zero initial weights are chosen, then the learning rate has no influence on a neuron's predicted class label. If you initialize all weights with zeros then every hidden unit will get zero independent of the input since the weight matrix is all zeros and multiplication will result in zero. So, when all the hidden neurons start with the zero weights, then all of them will follow the same gradient and for this reason starting with zeros affects only the scale of the weight vector, not the direction. Also, having zero weights to start with will prevent the network from learning. The errors backpropagated through the network is proportional to the value of the weights. If all the weights are the same, then the backpropagated errors will be the same, so all of the weights will be updated by the same amount which means the whole process was useless. To avoid this problem, the initial weights of the network should be unequal a way of doing this is to assign random values to weights.

# %% [markdown]
# ## Learning Rate

# %%
INPUT_SHAPE = 28 * 28
LEARNING_RATE = 0.001
EPOCHS = 20
NUM_CLASSES = 20
BATCH_SIZE = 64
TRAINLOADER = generateTrainLoader(train_dataset_matrix , train_labels_matrix , NUM_CLASSES , BATCH_SIZE)
TESTLOADER = generateTestLoader(test_dataset_matrix , test_labels_matrix , NUM_CLASSES , BATCH_SIZE)


network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(30 , input_shape = INPUT_SHAPE, activation = Relu(), weight_initializer = "uniform")
network.add_layer(NUM_CLASSES , activation = Identical(), weight_initializer = "uniform")
network.set_training_param(loss = CrossEntropy() , lr = LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 58.178971215351815	Average Loss: 1.4768819539056393
# 	Test: Average Accuracy: 62.00354609929077	Average Loss: 1.355892506710028
# Epoch 2:
# 	Train: Average Accuracy: 76.26765724946695	Average Loss: 0.8655954191931076
# 	Test: Average Accuracy: 66.1613475177305	Average Loss: 1.2165055813230448
# Epoch 3:
# 	Train: Average Accuracy: 79.13612739872069	Average Loss: 0.7641494343937469
# 	Test: Average Accuracy: 68.56382978723404	Average Loss: 1.1391483501724085
# Epoch 4:
# 	Train: Average Accuracy: 81.00179904051173	Average Loss: 0.6962329406848429
# 	Test: Average Accuracy: 70.37234042553192	Average Loss: 1.077130731573483
# Epoch 5:
# 	Train: Average Accuracy: 82.49433635394456	Average Loss: 0.6417369698097634
# 	Test: Average Accuracy: 71.72872340425532	Average Loss: 1.026201491871417
# Epoch 6:
# 	Train: Average Accuracy: 83.55377132196162	Average Loss: 0.5972652211164089
# 	Test: Average Accuracy: 72.9366134751773	Average Loss: 0.987033495170152
# Epoch 7:
# 	Train: Average Accuracy: 84.55157249466951	Average Loss: 0.5622182023164126
# 	Test: Average Accuracy: 73.81870567375887	Average Loss: 0.9567404763661411
# Epoch 8:
# 	Train: Average Accuracy: 85.3378198294243	Average Loss: 0.5349007405201227
# 	Test: Average Accuracy: 74.46365248226951	Average Loss: 0.9343920350942998
# Epoch 9:
# 	Train: Average Accuracy: 85.80257196162047	Average Loss: 0.5134094616811491
# 	Test: Average Accuracy: 75.10195035460994	Average Loss: 0.9200467646174044
# Epoch 10:
# 	Train: Average Accuracy: 86.26732409381663	Average Loss: 0.49616924558439
# 	Test: Average Accuracy: 75.21498226950355	Average Loss: 0.9123693632551984
# Epoch 11:
# 	Train: Average Accuracy: 86.73873933901919	Average Loss: 0.4817643426404669
# 	Test: Average Accuracy: 75.40115248226951	Average Loss: 0.9061598076925987
# Epoch 12:
# 	Train: Average Accuracy: 87.04191098081023	Average Loss: 0.46942652080843295
# 	Test: Average Accuracy: 75.63164893617021	Average Loss: 0.9025829338243565
# Epoch 13:
# 	Train: Average Accuracy: 87.2901119402985	Average Loss: 0.4585966835857149
# 	Test: Average Accuracy: 75.77127659574468	Average Loss: 0.8999463438182171
# Epoch 14:
# 	Train: Average Accuracy: 87.58162313432835	Average Loss: 0.4489972880487531
# 	Test: Average Accuracy: 75.95744680851064	Average Loss: 0.8984769575067016
# Epoch 15:
# 	Train: Average Accuracy: 87.78651385927505	Average Loss: 0.440340091084417
# 	Test: Average Accuracy: 75.98404255319149	Average Loss: 0.8985409379557754
# Epoch 16:
# 	Train: Average Accuracy: 87.99307036247335	Average Loss: 0.4326191946614399
# 	Test: Average Accuracy: 76.0372340425532	Average Loss: 0.8975968888935004
# Epoch 17:
# 	Train: Average Accuracy: 88.17464019189765	Average Loss: 0.425530016867565
# 	Test: Average Accuracy: 76.12367021276596	Average Loss: 0.8989589089924382
# Epoch 18:
# 	Train: Average Accuracy: 88.35454424307036	Average Loss: 0.41902986523321634
# 	Test: Average Accuracy: 76.05053191489361	Average Loss: 0.9003002027702263
# Epoch 19:
# 	Train: Average Accuracy: 88.48947228144989	Average Loss: 0.4131072679059372
# 	Test: Average Accuracy: 76.08377659574468	Average Loss: 0.9022509944230408
# Epoch 20:
# 	Train: Average Accuracy: 88.62106876332622	Average Loss: 0.4076496304254847
# 	Test: Average Accuracy: 76.06604609929079	Average Loss: 0.9051558722249077

# %%
INPUT_SHAPE = 28 * 28
LEARNING_RATE = 0.01
EPOCHS = 20
NUM_CLASSES = 20
BATCH_SIZE = 64
TRAINLOADER = generateTrainLoader(train_dataset_matrix , train_labels_matrix , NUM_CLASSES , BATCH_SIZE)
TESTLOADER = generateTestLoader(test_dataset_matrix , test_labels_matrix , NUM_CLASSES , BATCH_SIZE)


network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(30 , input_shape = INPUT_SHAPE, activation = Relu(), weight_initializer = "uniform")
network.add_layer(NUM_CLASSES , activation = Identical(), weight_initializer = "uniform")
network.set_training_param(loss = CrossEntropy() , lr = LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 5.600346481876333	Average Loss: 2.9715821778381564
# 	Test: Average Accuracy: 5.6227836879432616	Average Loss: 2.949812932419543
# Epoch 2:
# 	Train: Average Accuracy: 5.588686034115138	Average Loss: 2.951386123930466
# 	Test: Average Accuracy: 5.6227836879432616	Average Loss: 2.94981443264841
# Epoch 3:
# 	Train: Average Accuracy: 5.5903518123667375	Average Loss: 2.95138135662561
# 	Test: Average Accuracy: 5.6227836879432616	Average Loss: 2.949814287361184
# Epoch 4:
# 	Train: Average Accuracy: 5.5903518123667375	Average Loss: 2.951377877972966
# 	Test: Average Accuracy: 5.6227836879432616	Average Loss: 2.9498130544858725
# Epoch 5:
# 	Train: Average Accuracy: 5.5903518123667375	Average Loss: 2.951374735388756
# 	Test: Average Accuracy: 5.6227836879432616	Average Loss: 2.9498124261786534
# Epoch 6:
# 	Train: Average Accuracy: 5.5903518123667375	Average Loss: 2.9513718181198585
# 	Test: Average Accuracy: 5.6227836879432616	Average Loss: 2.9498104432669936
# Epoch 7:
# 	Train: Average Accuracy: 5.5903518123667375	Average Loss: 2.951368227921626
# 	Test: Average Accuracy: 5.629432624113474	Average Loss: 2.9498065707009373
# Epoch 8:
# 	Train: Average Accuracy: 5.588686034115138	Average Loss: 2.951353077646379
# 	Test: Average Accuracy: 5.6626773049645385	Average Loss: 2.9497316596049306
# Epoch 9:
# 	Train: Average Accuracy: 8.776985607675906	Average Loss: 2.7887177643947556
# 	Test: Average Accuracy: 11.110372340425531	Average Loss: 2.6287523298071855
# Epoch 10:
# 	Train: Average Accuracy: 27.123867270788914	Average Loss: 2.26931272441541
# 	Test: Average Accuracy: 31.05939716312057	Average Loss: 2.3511732139446666
# Epoch 11:
# 	Train: Average Accuracy: 35.09128464818763	Average Loss: 2.063169218068809
# 	Test: Average Accuracy: 30.398936170212767	Average Loss: 2.2756128830250777
# Epoch 12:
# 	Train: Average Accuracy: 42.17417377398721	Average Loss: 1.8356804946474323
# 	Test: Average Accuracy: 38.90735815602837	Average Loss: 2.038502150181119
# Epoch 13:
# 	Train: Average Accuracy: 48.59408315565032	Average Loss: 1.6993325484307764
# 	Test: Average Accuracy: 45.56294326241135	Average Loss: 1.968872953509366
# Epoch 14:
# 	Train: Average Accuracy: 52.548640724946694	Average Loss: 1.5899699494853001
# 	Test: Average Accuracy: 47.200797872340424	Average Loss: 1.9217238393564637
# Epoch 15:
# 	Train: Average Accuracy: 53.916244669509595	Average Loss: 1.5470443222564325
# 	Test: Average Accuracy: 49.038120567375884	Average Loss: 1.8853539902263898
# Epoch 16:
# 	Train: Average Accuracy: 57.07122867803838	Average Loss: 1.4290455000245623
# 	Test: Average Accuracy: 50.48980496453901	Average Loss: 1.7872967393187653
# Epoch 17:
# 	Train: Average Accuracy: 58.0040644989339	Average Loss: 1.3915401494915312
# 	Test: Average Accuracy: 51.221187943262414	Average Loss: 1.7605202244850915
# Epoch 18:
# 	Train: Average Accuracy: 58.46048773987207	Average Loss: 1.3757677053450426
# 	Test: Average Accuracy: 50.97960992907801	Average Loss: 1.7836427990235888
# Epoch 19:
# 	Train: Average Accuracy: 60.44776119402985	Average Loss: 1.3028614644126373
# 	Test: Average Accuracy: 52.972074468085104	Average Loss: 1.6614558270513893
# Epoch 20:
# 	Train: Average Accuracy: 63.06636460554371	Average Loss: 1.2201672914414659
# 	Test: Average Accuracy: 54.736258865248224	Average Loss: 1.638652668112959

# %%
INPUT_SHAPE = 28 * 28
LEARNING_RATE = 0.1
EPOCHS = 20
NUM_CLASSES = 20
BATCH_SIZE = 64
TRAINLOADER = generateTrainLoader(train_dataset_matrix , train_labels_matrix , NUM_CLASSES , BATCH_SIZE)
TESTLOADER = generateTestLoader(test_dataset_matrix , test_labels_matrix , NUM_CLASSES , BATCH_SIZE)


network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(30 , input_shape = INPUT_SHAPE, activation = Relu(), weight_initializer = "uniform")
network.add_layer(NUM_CLASSES , activation = Identical(), weight_initializer = "uniform")
network.set_training_param(loss = CrossEntropy() , lr = LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 5.640325159914712	Average Loss: 3.1321971011329395
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 2:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 3:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 4:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 5:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 6:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 7:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 8:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 9:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 10:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 11:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 12:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 13:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 14:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 15:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 16:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 17:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 18:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 19:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405
# Epoch 20:
# 	Train: Average Accuracy: 5.658648720682303	Average Loss: 2.977034845950102
# 	Test: Average Accuracy: 5.69813829787234	Average Loss: 2.967495592937405

# %%
INPUT_SHAPE = 28 * 28
LEARNING_RATE = 0.0001
EPOCHS = 20
NUM_CLASSES = 20
BATCH_SIZE = 64
TRAINLOADER = generateTrainLoader(train_dataset_matrix , train_labels_matrix , NUM_CLASSES , BATCH_SIZE)
TESTLOADER = generateTestLoader(test_dataset_matrix , test_labels_matrix , NUM_CLASSES , BATCH_SIZE)


network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(30 , input_shape = INPUT_SHAPE, activation = Relu(), weight_initializer = "uniform")
network.add_layer(NUM_CLASSES , activation = Identical(), weight_initializer = "uniform")
network.set_training_param(loss = CrossEntropy() , lr = LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 11.322294776119403	Average Loss: 2.854677081887793
# 	Test: Average Accuracy: 22.728280141843975	Average Loss: 2.668491597206269
# Epoch 2:
# 	Train: Average Accuracy: 40.17357409381663	Average Loss: 2.247960472828343
# 	Test: Average Accuracy: 43.24911347517731	Average Loss: 2.1079261565042477
# Epoch 3:
# 	Train: Average Accuracy: 57.845815565031984	Average Loss: 1.630623989779955
# 	Test: Average Accuracy: 49.827127659574465	Average Loss: 1.7539346302019594
# Epoch 4:
# 	Train: Average Accuracy: 64.0591684434968	Average Loss: 1.3149555662678394
# 	Test: Average Accuracy: 54.410460992907794	Average Loss: 1.5873370072930424
# Epoch 5:
# 	Train: Average Accuracy: 67.60227878464819	Average Loss: 1.1691384476062705
# 	Test: Average Accuracy: 57.30274822695035	Average Loss: 1.4932626936188598
# Epoch 6:
# 	Train: Average Accuracy: 69.76779051172709	Average Loss: 1.08694424997412
# 	Test: Average Accuracy: 59.151152482269495	Average Loss: 1.4317471294986357
# Epoch 7:
# 	Train: Average Accuracy: 71.22534648187633	Average Loss: 1.0327831590430296
# 	Test: Average Accuracy: 60.79122340425532	Average Loss: 1.3869414750645817
# Epoch 8:
# 	Train: Average Accuracy: 72.31976279317698	Average Loss: 0.9929933442066342
# 	Test: Average Accuracy: 61.83510638297872	Average Loss: 1.3522954506287737
# Epoch 9:
# 	Train: Average Accuracy: 73.2392723880597	Average Loss: 0.961944482454076
# 	Test: Average Accuracy: 62.726063829787236	Average Loss: 1.3248551551248968
# Epoch 10:
# 	Train: Average Accuracy: 74.05050639658849	Average Loss: 0.9369341411721628
# 	Test: Average Accuracy: 63.57047872340426	Average Loss: 1.3028456464655371
# Epoch 11:
# 	Train: Average Accuracy: 74.72348081023455	Average Loss: 0.9163222944278928
# 	Test: Average Accuracy: 64.36170212765957	Average Loss: 1.2849140320595036
# Epoch 12:
# 	Train: Average Accuracy: 75.21821695095949	Average Loss: 0.8989498592779204
# 	Test: Average Accuracy: 64.88031914893617	Average Loss: 1.269970262605861
# Epoch 13:
# 	Train: Average Accuracy: 75.68796641791045	Average Loss: 0.8839849451469821
# 	Test: Average Accuracy: 65.21054964539007	Average Loss: 1.257231496983548
# Epoch 14:
# 	Train: Average Accuracy: 76.08109008528784	Average Loss: 0.8708496031524043
# 	Test: Average Accuracy: 65.60283687943263	Average Loss: 1.2461529768617572
# Epoch 15:
# 	Train: Average Accuracy: 76.45922174840085	Average Loss: 0.8591234972207143
# 	Test: Average Accuracy: 65.82890070921987	Average Loss: 1.2363808928291424
# Epoch 16:
# 	Train: Average Accuracy: 76.77405383795309	Average Loss: 0.8485218974220003
# 	Test: Average Accuracy: 66.14804964539007	Average Loss: 1.227648566021401
# Epoch 17:
# 	Train: Average Accuracy: 77.05057302771856	Average Loss: 0.8388119679688479
# 	Test: Average Accuracy: 66.34530141843972	Average Loss: 1.2196774611519643
# Epoch 18:
# 	Train: Average Accuracy: 77.29710820895522	Average Loss: 0.829834100336045
# 	Test: Average Accuracy: 66.60460992907801	Average Loss: 1.2123699281497151
# Epoch 19:
# 	Train: Average Accuracy: 77.5453091684435	Average Loss: 0.8214506886122999
# 	Test: Average Accuracy: 66.78413120567376	Average Loss: 1.205488681883726
# Epoch 20:
# 	Train: Average Accuracy: 77.82182835820896	Average Loss: 0.8135309332793574
# 	Test: Average Accuracy: 66.99024822695036	Average Loss: 1.1989895517807385

# %%
INPUT_SHAPE = 28 * 28
LEARNING_RATE = 0.0035
EPOCHS = 20
NUM_CLASSES = 20
BATCH_SIZE = 64
TRAINLOADER = generateTrainLoader(train_dataset_matrix , train_labels_matrix , NUM_CLASSES , BATCH_SIZE)
TESTLOADER = generateTestLoader(test_dataset_matrix , test_labels_matrix , NUM_CLASSES , BATCH_SIZE)


network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(30 , input_shape = INPUT_SHAPE, activation = Relu(), weight_initializer = "uniform")
network.add_layer(NUM_CLASSES , activation = Identical(), weight_initializer = "uniform")
network.set_training_param(loss = CrossEntropy() , lr = LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 57.75086620469083	Average Loss: 1.4537424266291636
# 	Test: Average Accuracy: 68.75886524822695	Average Loss: 1.1403461432090212
# Epoch 2:
# 	Train: Average Accuracy: 80.21055437100213	Average Loss: 0.7094497321305481
# 	Test: Average Accuracy: 72.07003546099291	Average Loss: 1.013290320836214
# Epoch 3:
# 	Train: Average Accuracy: 82.48600746268657	Average Loss: 0.6241300418722757
# 	Test: Average Accuracy: 73.84530141843973	Average Loss: 0.9590306384112178
# Epoch 4:
# 	Train: Average Accuracy: 83.80530383795309	Average Loss: 0.5732070900952384
# 	Test: Average Accuracy: 74.7628546099291	Average Loss: 0.9303130656495107
# Epoch 5:
# 	Train: Average Accuracy: 84.88472814498934	Average Loss: 0.5329478114237235
# 	Test: Average Accuracy: 75.46542553191489	Average Loss: 0.9190286479970171
# Epoch 6:
# 	Train: Average Accuracy: 85.72927771855011	Average Loss: 0.5022700592143791
# 	Test: Average Accuracy: 76.18351063829788	Average Loss: 0.9032384609073142
# Epoch 7:
# 	Train: Average Accuracy: 86.54550906183368	Average Loss: 0.4777904927980941
# 	Test: Average Accuracy: 76.54920212765957	Average Loss: 0.8925386588851213
# Epoch 8:
# 	Train: Average Accuracy: 87.06190031982942	Average Loss: 0.4579824164051471
# 	Test: Average Accuracy: 76.875	Average Loss: 0.8836093046126215
# Epoch 9:
# 	Train: Average Accuracy: 87.5	Average Loss: 0.44214804352295506
# 	Test: Average Accuracy: 77.11436170212765	Average Loss: 0.8806960353520021
# Epoch 10:
# 	Train: Average Accuracy: 87.82815831556503	Average Loss: 0.42945566048841716
# 	Test: Average Accuracy: 77.15203900709218	Average Loss: 0.8821561231385162
# Epoch 11:
# 	Train: Average Accuracy: 88.11467217484008	Average Loss: 0.41859100992997544
# 	Test: Average Accuracy: 77.09884751773049	Average Loss: 0.8848777512030196
# Epoch 12:
# 	Train: Average Accuracy: 88.39952025586354	Average Loss: 0.4095976374731176
# 	Test: Average Accuracy: 77.11879432624113	Average Loss: 0.8875474583956213
# Epoch 13:
# 	Train: Average Accuracy: 88.58775319829424	Average Loss: 0.40158702479305497
# 	Test: Average Accuracy: 77.25842198581559	Average Loss: 0.891069219637462
# Epoch 14:
# 	Train: Average Accuracy: 88.80930170575692	Average Loss: 0.39479323903323676
# 	Test: Average Accuracy: 77.23182624113474	Average Loss: 0.895783788035626
# Epoch 15:
# 	Train: Average Accuracy: 89.00253198294243	Average Loss: 0.3884090149390504
# 	Test: Average Accuracy: 77.25842198581559	Average Loss: 0.8973418592055664
# Epoch 16:
# 	Train: Average Accuracy: 89.14079157782515	Average Loss: 0.38296415749774293
# 	Test: Average Accuracy: 77.17863475177305	Average Loss: 0.9049461039253639
# Epoch 17:
# 	Train: Average Accuracy: 89.28904584221749	Average Loss: 0.37746644901068255
# 	Test: Average Accuracy: 77.05895390070921	Average Loss: 0.9144265106788675
# Epoch 18:
# 	Train: Average Accuracy: 89.47894456289978	Average Loss: 0.37251652796283263
# 	Test: Average Accuracy: 77.05230496453899	Average Loss: 0.9173038384681391
# Epoch 19:
# 	Train: Average Accuracy: 89.63219616204691	Average Loss: 0.3680089016306767
# 	Test: Average Accuracy: 77.09219858156027	Average Loss: 0.9233444935189946
# Epoch 20:
# 	Train: Average Accuracy: 89.70715618336887	Average Loss: 0.363980031811199
# 	Test: Average Accuracy: 77.15868794326241	Average Loss: 0.9307639708502826

# %% [markdown]
# By checking multiple values for learning rate, optimal learning rate was around 0.003 and 0.004 so I chose 0.0035.
#
# The learning rate controls how quickly the model is adapted to the problem. Smaller learning rates require more training epochs given the smaller changes made to the weights each update, whereas larger learning rates result in rapid changes and require fewer training epochs.
#
# If the learning rate is low, then training is more reliable, but optimization will take a lot of time because steps towards the minimum of the loss function are tiny. If the learning rate is high, then training may not converge or even diverge. Weight changes can be so big that the optimizer overshoots the minimum and makes the loss worse.
#
# By taking a look at the results above as we move from 0.001 learning rate towards 0.1 we can see that the accuracy drops noticeably also when lowering learning rate to 0.0001 we can see that the accuracy with 20 epochs isn't good. The results approves the explanations above. Too high there might be overshoot therefore lower rates and higher loss, Too low the network won't converge even if it does it'll take too much time so it won't be efficient.

# %%
learningRates = [0.001 , 0.01 , 0.1 , 0.0001 , 0.0035]
testAccuracy = [76.06604609929079 , 54.736258865248224 , 5.69813829787234 , 66.99024822695036 , 77.15868794326241]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.title("Test accuracy with respect to learning rate")
plt.xlabel("Learning rate")
plt.ylabel("Test accuracy percentage")
ax.bar(learningRates , testAccuracy , width = 0.001)
plt.show()

# %% [markdown]
# ## Activation Function

# %%
INPUT_SHAPE = 28 * 28
LEARNING_RATE = 0.0035
EPOCHS = 20
NUM_CLASSES = 20
BATCH_SIZE = 64
TRAINLOADER = generateTrainLoader(train_dataset_matrix , train_labels_matrix , NUM_CLASSES , BATCH_SIZE)
TESTLOADER = generateTestLoader(test_dataset_matrix , test_labels_matrix , NUM_CLASSES , BATCH_SIZE)


network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(30 , input_shape = INPUT_SHAPE, activation = Sigmoid(), weight_initializer = "uniform")
network.add_layer(NUM_CLASSES , activation = Identical(), weight_initializer = "uniform")
network.set_training_param(loss = CrossEntropy() , lr = LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 25.951159381663114	Average Loss: 2.4424121575961077
# 	Test: Average Accuracy: 45.704787234042556	Average Loss: 1.852445325840845
# Epoch 2:
# 	Train: Average Accuracy: 67.86547174840085	Average Loss: 1.206865315780307
# 	Test: Average Accuracy: 60.944148936170215	Average Loss: 1.3583545221271132
# Epoch 3:
# 	Train: Average Accuracy: 75.13825959488273	Average Loss: 0.9072533783690273
# 	Test: Average Accuracy: 65.62943262411348	Average Loss: 1.2102771285508531
# Epoch 4:
# 	Train: Average Accuracy: 78.09001865671642	Average Loss: 0.7956122970271343
# 	Test: Average Accuracy: 67.80363475177305	Average Loss: 1.1267167151813466
# Epoch 5:
# 	Train: Average Accuracy: 79.7008262260128	Average Loss: 0.7308118246617651
# 	Test: Average Accuracy: 69.3572695035461	Average Loss: 1.0728159277027967
# Epoch 6:
# 	Train: Average Accuracy: 80.95015991471216	Average Loss: 0.6869021958930397
# 	Test: Average Accuracy: 70.43439716312058	Average Loss: 1.036671096341574
# Epoch 7:
# 	Train: Average Accuracy: 81.73140991471216	Average Loss: 0.6548851046641941
# 	Test: Average Accuracy: 71.1258865248227	Average Loss: 1.0115183398736127
# Epoch 8:
# 	Train: Average Accuracy: 82.4160447761194	Average Loss: 0.6300119614033104
# 	Test: Average Accuracy: 71.88386524822695	Average Loss: 0.9929906769586854
# Epoch 9:
# 	Train: Average Accuracy: 83.04570895522389	Average Loss: 0.6094274041393517
# 	Test: Average Accuracy: 72.2628546099291	Average Loss: 0.9781325871165157
# Epoch 10:
# 	Train: Average Accuracy: 83.52711886993603	Average Loss: 0.5918112524080368
# 	Test: Average Accuracy: 72.76152482269505	Average Loss: 0.9658759646746012
# Epoch 11:
# 	Train: Average Accuracy: 83.90525053304904	Average Loss: 0.5765756618970729
# 	Test: Average Accuracy: 73.22695035460994	Average Loss: 0.9557259685489803
# Epoch 12:
# 	Train: Average Accuracy: 84.20175906183368	Average Loss: 0.5631896630281298
# 	Test: Average Accuracy: 73.50177304964538	Average Loss: 0.9471597155799085
# Epoch 13:
# 	Train: Average Accuracy: 84.46162046908316	Average Loss: 0.551252799256205
# 	Test: Average Accuracy: 73.81427304964538	Average Loss: 0.9400021386678711
# Epoch 14:
# 	Train: Average Accuracy: 84.73813965884861	Average Loss: 0.5404720359355799
# 	Test: Average Accuracy: 74.0381205673759	Average Loss: 0.9340497023239707
# Epoch 15:
# 	Train: Average Accuracy: 84.99633528784648	Average Loss: 0.5305778910365682
# 	Test: Average Accuracy: 74.10460992907802	Average Loss: 0.9290881222270028
# Epoch 16:
# 	Train: Average Accuracy: 85.26952292110875	Average Loss: 0.5214870231051936
# 	Test: Average Accuracy: 74.30407801418441	Average Loss: 0.924996438869632
# Epoch 17:
# 	Train: Average Accuracy: 85.53105010660981	Average Loss: 0.5131403495809663
# 	Test: Average Accuracy: 74.36391843971633	Average Loss: 0.9216641215909944
# Epoch 18:
# 	Train: Average Accuracy: 85.76425906183368	Average Loss: 0.5054442278048724
# 	Test: Average Accuracy: 74.4991134751773	Average Loss: 0.9189513845696717
# Epoch 19:
# 	Train: Average Accuracy: 85.96415245202559	Average Loss: 0.4983190271177736
# 	Test: Average Accuracy: 74.57225177304963	Average Loss: 0.9167304554858323
# Epoch 20:
# 	Train: Average Accuracy: 86.1440565031983	Average Loss: 0.4917091682662288
# 	Test: Average Accuracy: 74.66755319148936	Average Loss: 0.9148889168161554

# %%
INPUT_SHAPE = 28 * 28
LEARNING_RATE = 0.0035
EPOCHS = 20
NUM_CLASSES = 20
BATCH_SIZE = 64
TRAINLOADER = generateTrainLoader(train_dataset_matrix , train_labels_matrix , NUM_CLASSES , BATCH_SIZE)
TESTLOADER = generateTestLoader(test_dataset_matrix , test_labels_matrix , NUM_CLASSES , BATCH_SIZE)


network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(30 , input_shape = INPUT_SHAPE, activation = Tanh(), weight_initializer = "uniform")
network.add_layer(NUM_CLASSES , activation = Identical(), weight_initializer = "uniform")
network.set_training_param(loss = CrossEntropy() , lr = LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 46.07542643923241	Average Loss: 1.804092978603489
# 	Test: Average Accuracy: 59.421542553191486	Average Loss: 1.437972982433124
# Epoch 2:
# 	Train: Average Accuracy: 73.57409381663113	Average Loss: 0.9301550336510509
# 	Test: Average Accuracy: 64.0979609929078	Average Loss: 1.2648256097758959
# Epoch 3:
# 	Train: Average Accuracy: 76.87066897654584	Average Loss: 0.8167961433354676
# 	Test: Average Accuracy: 65.59840425531915	Average Loss: 1.2230477264012427
# Epoch 4:
# 	Train: Average Accuracy: 78.65305170575692	Average Loss: 0.751531246269135
# 	Test: Average Accuracy: 67.3936170212766	Average Loss: 1.1713270838613652
# Epoch 5:
# 	Train: Average Accuracy: 79.95569029850746	Average Loss: 0.7052343388965899
# 	Test: Average Accuracy: 67.92331560283688	Average Loss: 1.1515581180778955
# Epoch 6:
# 	Train: Average Accuracy: 80.89685501066099	Average Loss: 0.6746664283498262
# 	Test: Average Accuracy: 68.94503546099291	Average Loss: 1.132388411588174
# Epoch 7:
# 	Train: Average Accuracy: 81.41824360341151	Average Loss: 0.6531691726609591
# 	Test: Average Accuracy: 69.35062056737588	Average Loss: 1.1199831656426749
# Epoch 8:
# 	Train: Average Accuracy: 81.87966417910448	Average Loss: 0.6358298735717229
# 	Test: Average Accuracy: 69.61436170212765	Average Loss: 1.1135924366626921
# Epoch 9:
# 	Train: Average Accuracy: 82.30110607675905	Average Loss: 0.6209090516980487
# 	Test: Average Accuracy: 69.69414893617021	Average Loss: 1.1085078207917882
# Epoch 10:
# 	Train: Average Accuracy: 82.73254264392324	Average Loss: 0.6076248126600032
# 	Test: Average Accuracy: 69.92242907801419	Average Loss: 1.1040542946974972
# Epoch 11:
# 	Train: Average Accuracy: 83.09734808102345	Average Loss: 0.5965039610553833
# 	Test: Average Accuracy: 70.14627659574468	Average Loss: 1.1022576868712888
# Epoch 12:
# 	Train: Average Accuracy: 83.28558102345416	Average Loss: 0.5868817240066122
# 	Test: Average Accuracy: 70.54521276595744	Average Loss: 1.0984221514129973
# Epoch 13:
# 	Train: Average Accuracy: 83.5837553304904	Average Loss: 0.5768095877758151
# 	Test: Average Accuracy: 70.79787234042553	Average Loss: 1.0932920717022
# Epoch 14:
# 	Train: Average Accuracy: 83.90691631130063	Average Loss: 0.5655536068806769
# 	Test: Average Accuracy: 70.99069148936171	Average Loss: 1.0854373092004106
# Epoch 15:
# 	Train: Average Accuracy: 84.23507462686567	Average Loss: 0.5529999065054196
# 	Test: Average Accuracy: 71.30984042553192	Average Loss: 1.0785274177181063
# Epoch 16:
# 	Train: Average Accuracy: 84.60820895522389	Average Loss: 0.5411105652586572
# 	Test: Average Accuracy: 71.46498226950355	Average Loss: 1.0712729514781607
# Epoch 17:
# 	Train: Average Accuracy: 84.88306236673775	Average Loss: 0.5304117197487971
# 	Test: Average Accuracy: 71.66666666666666	Average Loss: 1.0639466140204883
# Epoch 18:
# 	Train: Average Accuracy: 85.11460554371003	Average Loss: 0.5205321389561053
# 	Test: Average Accuracy: 71.72872340425532	Average Loss: 1.0589339233200725
# Epoch 19:
# 	Train: Average Accuracy: 85.44442963752665	Average Loss: 0.5114040521452221
# 	Test: Average Accuracy: 71.80851063829788	Average Loss: 1.059643248281813
# Epoch 20:
# 	Train: Average Accuracy: 85.65098614072495	Average Loss: 0.502929410876448
# 	Test: Average Accuracy: 71.94813829787235	Average Loss: 1.0620568963198378

# %%
INPUT_SHAPE = 28 * 28
LEARNING_RATE = 0.0035
EPOCHS = 20
NUM_CLASSES = 20
BATCH_SIZE = 64
TRAINLOADER = generateTrainLoader(train_dataset_matrix , train_labels_matrix , NUM_CLASSES , BATCH_SIZE)
TESTLOADER = generateTestLoader(test_dataset_matrix , test_labels_matrix , NUM_CLASSES , BATCH_SIZE)


network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(30 , input_shape = INPUT_SHAPE, activation = LeakyRelu(), weight_initializer = "uniform")
network.add_layer(NUM_CLASSES , activation = Identical(), weight_initializer = "uniform")
network.set_training_param(loss = CrossEntropy() , lr = LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 69.64785447761194	Average Loss: 1.1011777915366618
# 	Test: Average Accuracy: 70.7557624113475	Average Loss: 1.0370865826973885
# Epoch 2:
# 	Train: Average Accuracy: 82.97741204690831	Average Loss: 0.6041814746926142
# 	Test: Average Accuracy: 73.98271276595744	Average Loss: 0.9204186632594056
# Epoch 3:
# 	Train: Average Accuracy: 85.20622334754798	Average Loss: 0.5229843514001792
# 	Test: Average Accuracy: 75.41445035460994	Average Loss: 0.8833941321415867
# Epoch 4:
# 	Train: Average Accuracy: 86.41058102345416	Average Loss: 0.48330144260897967
# 	Test: Average Accuracy: 75.78014184397165	Average Loss: 0.8750199240976185
# Epoch 5:
# 	Train: Average Accuracy: 87.1235341151386	Average Loss: 0.4570902332346356
# 	Test: Average Accuracy: 76.36968085106383	Average Loss: 0.860946913512459
# Epoch 6:
# 	Train: Average Accuracy: 87.54331023454158	Average Loss: 0.4385004721781792
# 	Test: Average Accuracy: 76.60017730496453	Average Loss: 0.8633332353587598
# Epoch 7:
# 	Train: Average Accuracy: 87.92310767590618	Average Loss: 0.42398696034471606
# 	Test: Average Accuracy: 76.75975177304963	Average Loss: 0.8628811446883488
# Epoch 8:
# 	Train: Average Accuracy: 88.30457089552239	Average Loss: 0.4124283568002657
# 	Test: Average Accuracy: 76.9570035460993	Average Loss: 0.8627157297613433
# Epoch 9:
# 	Train: Average Accuracy: 88.54111140724947	Average Loss: 0.4025513737288741
# 	Test: Average Accuracy: 76.96365248226951	Average Loss: 0.8660573159483623
# Epoch 10:
# 	Train: Average Accuracy: 88.79097814498934	Average Loss: 0.39406861464381643
# 	Test: Average Accuracy: 77.18971631205675	Average Loss: 0.8661950124426531
# Epoch 11:
# 	Train: Average Accuracy: 88.98920575692964	Average Loss: 0.38650337114728167
# 	Test: Average Accuracy: 76.91710992907802	Average Loss: 0.874242819018713
# Epoch 12:
# 	Train: Average Accuracy: 89.20575692963753	Average Loss: 0.3799784034205085
# 	Test: Average Accuracy: 77.08998226950355	Average Loss: 0.8752198862487397
# Epoch 13:
# 	Train: Average Accuracy: 89.37566631130063	Average Loss: 0.37406732310867047
# 	Test: Average Accuracy: 77.11436170212765	Average Loss: 0.8818312255249317
# Epoch 14:
# 	Train: Average Accuracy: 89.52725213219617	Average Loss: 0.36845747234518017
# 	Test: Average Accuracy: 77.10106382978724	Average Loss: 0.8883800038688439
# Epoch 15:
# 	Train: Average Accuracy: 89.6588486140725	Average Loss: 0.3630934050159779
# 	Test: Average Accuracy: 77.21409574468085	Average Loss: 0.891895200354067
# Epoch 16:
# 	Train: Average Accuracy: 89.75546375266525	Average Loss: 0.3584514962656646
# 	Test: Average Accuracy: 77.34707446808511	Average Loss: 0.8966147036096369
# Epoch 17:
# 	Train: Average Accuracy: 89.92204157782515	Average Loss: 0.35372828386218946
# 	Test: Average Accuracy: 77.37810283687942	Average Loss: 0.9010032672740084
# Epoch 18:
# 	Train: Average Accuracy: 90.03031716417911	Average Loss: 0.3492130283973984
# 	Test: Average Accuracy: 77.28501773049645	Average Loss: 0.9062551161872144
# Epoch 19:
# 	Train: Average Accuracy: 90.15858208955224	Average Loss: 0.345530376102079
# 	Test: Average Accuracy: 77.28501773049645	Average Loss: 0.9122483307816073
# Epoch 20:
# 	Train: Average Accuracy: 90.28351545842217	Average Loss: 0.3419439562728585
# 	Test: Average Accuracy: 77.19858156028367	Average Loss: 0.9173912487698355

# %% [markdown]
# LeakyRelu and Relu results are really close to each other but LeakyRelu result value is a bit higher so at the end I chose LeakyRelu.
#
# In Tanh and Sigmoid moving towards the ends of the function, y values react very little to the changes in x so the derivative values in these regions are very small and converge to 0. This is called the vanishing gradient and the learning is minimal meaning that it makes the learning process be very slow or even useless. We know that if 0, not any learning. When slow learning occurs, the optimization algorithm that minimizes error can be attached to local minimum values and cannot get maximum performance from the artificial neural network model.
#
# So by the explanation above Tanh and Sigmoid will result in vanishing gradient meaning that after a while the learning process will be very slow. So since we are using Stochastic Gradient Descent, these activation functions, Sigmoid and Tanh, won't be the best choice.
#
# Unlike Relu, LeakyRelu is more balanced and may therefore learn faster. Also LeakyRelu fixes the dying Relu problem, as it doesn’t have zero-slope parts.
#
# Dying relu problem: A Relu neuron is dead if it’s stuck in the negative side and always outputs 0. Because the slope of Relu in the negative range is also 0, once a neuron gets negative, it’s unlikely for it to recover. Such neurons are not playing any role in discriminating the input and is essentially useless. Over the time you may end up with a large part of your network doing nothing.
#
# Since LeakyRelu assigns a small non zero value for negative parts this will result in solving the problem mentioned above and this is the main advantage of LeakyRelu.

# %%
activationFuncs = ["Sigmoid" , "Tanh" , "LeakyRelu" , "Relu"]
testAccuracy = [74.66755319148936 , 71.94813829787235 , 77.19858156028367 , 77.15868794326241]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.title("Test accuracy with respect to activation function")
plt.xlabel("Activation function")
plt.ylabel("Test accuracy percentage")
ax.bar(activationFuncs , testAccuracy)
plt.show()

# %% [markdown]
# ## Batch Size

# %%
INPUT_SHAPE = 28 * 28
LEARNING_RATE = 0.0035
EPOCHS = 20
NUM_CLASSES = 20
BATCH_SIZE = 16
TRAINLOADER = generateTrainLoader(train_dataset_matrix , train_labels_matrix , NUM_CLASSES , BATCH_SIZE)
TESTLOADER = generateTestLoader(test_dataset_matrix , test_labels_matrix , NUM_CLASSES , BATCH_SIZE)


network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(30 , input_shape = INPUT_SHAPE, activation = LeakyRelu(), weight_initializer = "uniform")
network.add_layer(NUM_CLASSES , activation = Identical(), weight_initializer = "uniform")
network.set_training_param(loss = CrossEntropy() , lr = LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 71.315	Average Loss: 1.0170673777616757
# 	Test: Average Accuracy: 71.47521321961621	Average Loss: 1.0265599160048817
# Epoch 2:
# 	Train: Average Accuracy: 82.68	Average Loss: 0.6157877898995765
# 	Test: Average Accuracy: 74.57356076759062	Average Loss: 0.9066326772848244
# Epoch 3:
# 	Train: Average Accuracy: 84.77833333333334	Average Loss: 0.535350257210532
# 	Test: Average Accuracy: 76.04610874200426	Average Loss: 0.8705808461969916
# Epoch 4:
# 	Train: Average Accuracy: 85.945	Average Loss: 0.49282152180746797
# 	Test: Average Accuracy: 76.83901918976545	Average Loss: 0.847341205391866
# Epoch 5:
# 	Train: Average Accuracy: 86.82166666666667	Average Loss: 0.46375349600575344
# 	Test: Average Accuracy: 77.56529850746269	Average Loss: 0.8378334597439574
# Epoch 6:
# 	Train: Average Accuracy: 87.45833333333333	Average Loss: 0.4433425530926159
# 	Test: Average Accuracy: 77.65858208955224	Average Loss: 0.8409592034312217
# Epoch 7:
# 	Train: Average Accuracy: 87.84833333333333	Average Loss: 0.4284765682762878
# 	Test: Average Accuracy: 78.01839019189765	Average Loss: 0.8435299784167428
# Epoch 8:
# 	Train: Average Accuracy: 88.15	Average Loss: 0.41659854385620737
# 	Test: Average Accuracy: 78.03837953091684	Average Loss: 0.8486835638832378
# Epoch 9:
# 	Train: Average Accuracy: 88.42666666666666	Average Loss: 0.4067543512383824
# 	Test: Average Accuracy: 78.08502132196162	Average Loss: 0.851831672034344
# Epoch 10:
# 	Train: Average Accuracy: 88.64	Average Loss: 0.39862307110051615
# 	Test: Average Accuracy: 78.05836886993603	Average Loss: 0.8564674882962255
# Epoch 11:
# 	Train: Average Accuracy: 88.83666666666667	Average Loss: 0.391123264481144
# 	Test: Average Accuracy: 77.9117803837953	Average Loss: 0.8633597833810482
# Epoch 12:
# 	Train: Average Accuracy: 88.97666666666667	Average Loss: 0.38489012459482097
# 	Test: Average Accuracy: 77.81849680170576	Average Loss: 0.872406704199745
# Epoch 13:
# 	Train: Average Accuracy: 89.13833333333334	Average Loss: 0.37921161222696853
# 	Test: Average Accuracy: 77.88512793176972	Average Loss: 0.8760406826993774
# Epoch 14:
# 	Train: Average Accuracy: 89.25	Average Loss: 0.37394232017496387
# 	Test: Average Accuracy: 77.89179104477611	Average Loss: 0.8791462027159169
# Epoch 15:
# 	Train: Average Accuracy: 89.44333333333333	Average Loss: 0.3691305551963607
# 	Test: Average Accuracy: 77.89845415778251	Average Loss: 0.8869020879447459
# Epoch 16:
# 	Train: Average Accuracy: 89.62166666666667	Average Loss: 0.36476668718236505
# 	Test: Average Accuracy: 77.738539445629	Average Loss: 0.8941299042084795
# Epoch 17:
# 	Train: Average Accuracy: 89.68666666666667	Average Loss: 0.36071189324145164
# 	Test: Average Accuracy: 77.68523454157783	Average Loss: 0.8987331634758667
# Epoch 18:
# 	Train: Average Accuracy: 89.78166666666667	Average Loss: 0.35665432767893523
# 	Test: Average Accuracy: 77.63192963752665	Average Loss: 0.9056573013021635
# Epoch 19:
# 	Train: Average Accuracy: 89.91	Average Loss: 0.35300495348340666
# 	Test: Average Accuracy: 77.66524520255864	Average Loss: 0.9104902746408636
# Epoch 20:
# 	Train: Average Accuracy: 90.0	Average Loss: 0.3494507986426735
# 	Test: Average Accuracy: 77.60527718550107	Average Loss: 0.9174925288210845

# %%
INPUT_SHAPE = 28 * 28
LEARNING_RATE = 0.0035
EPOCHS = 20
NUM_CLASSES = 20
BATCH_SIZE = 32
TRAINLOADER = generateTrainLoader(train_dataset_matrix , train_labels_matrix , NUM_CLASSES , BATCH_SIZE)
TESTLOADER = generateTestLoader(test_dataset_matrix , test_labels_matrix , NUM_CLASSES , BATCH_SIZE)


network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(30 , input_shape = INPUT_SHAPE, activation = LeakyRelu(), weight_initializer = "uniform")
network.add_layer(NUM_CLASSES , activation = Identical(), weight_initializer = "uniform")
network.set_training_param(loss = CrossEntropy() , lr = LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 72.05	Average Loss: 1.0144157807147478
# 	Test: Average Accuracy: 71.37304548685147	Average Loss: 1.032771948979803
# Epoch 2:
# 	Train: Average Accuracy: 83.545	Average Loss: 0.5989382693438603
# 	Test: Average Accuracy: 74.56467661691543	Average Loss: 0.9244933375395132
# Epoch 3:
# 	Train: Average Accuracy: 85.61333333333333	Average Loss: 0.5178895106496411
# 	Test: Average Accuracy: 76.11718194740584	Average Loss: 0.8860678340956888
# Epoch 4:
# 	Train: Average Accuracy: 86.53166666666667	Average Loss: 0.4805079899280793
# 	Test: Average Accuracy: 76.5702736318408	Average Loss: 0.8809983089934426
# Epoch 5:
# 	Train: Average Accuracy: 87.185	Average Loss: 0.45621308765314694
# 	Test: Average Accuracy: 77.05890191897655	Average Loss: 0.873916232583509
# Epoch 6:
# 	Train: Average Accuracy: 87.68166666666667	Average Loss: 0.4379468334048757
# 	Test: Average Accuracy: 77.20549040511727	Average Loss: 0.8732692631854008
# Epoch 7:
# 	Train: Average Accuracy: 88.01333333333334	Average Loss: 0.4234217025312433
# 	Test: Average Accuracy: 77.43425728500355	Average Loss: 0.8747921745809782
# Epoch 8:
# 	Train: Average Accuracy: 88.38166666666666	Average Loss: 0.4112106371192465
# 	Test: Average Accuracy: 77.38095238095238	Average Loss: 0.8830972043349155
# Epoch 9:
# 	Train: Average Accuracy: 88.64333333333333	Average Loss: 0.40138023496291164
# 	Test: Average Accuracy: 77.31432125088841	Average Loss: 0.8873313738486681
# Epoch 10:
# 	Train: Average Accuracy: 88.92833333333333	Average Loss: 0.39247838295625137
# 	Test: Average Accuracy: 77.22103766879886	Average Loss: 0.8972894636539015
# Epoch 11:
# 	Train: Average Accuracy: 89.12	Average Loss: 0.38491325035940027
# 	Test: Average Accuracy: 77.14774342572849	Average Loss: 0.9052472968841595
# Epoch 12:
# 	Train: Average Accuracy: 89.34	Average Loss: 0.37831129316174905
# 	Test: Average Accuracy: 77.11664889836533	Average Loss: 0.9135607180163416
# Epoch 13:
# 	Train: Average Accuracy: 89.49	Average Loss: 0.3725862293171447
# 	Test: Average Accuracy: 77.07667022032695	Average Loss: 0.9176115453062518
# Epoch 14:
# 	Train: Average Accuracy: 89.65333333333334	Average Loss: 0.36685722259130876
# 	Test: Average Accuracy: 76.81680881307747	Average Loss: 0.928503787590545
# Epoch 15:
# 	Train: Average Accuracy: 89.80666666666667	Average Loss: 0.3615987330482332
# 	Test: Average Accuracy: 76.91009239516703	Average Loss: 0.93261639200691
# Epoch 16:
# 	Train: Average Accuracy: 89.91333333333333	Average Loss: 0.35677137371109857
# 	Test: Average Accuracy: 76.91675550817342	Average Loss: 0.9409517830194664
# Epoch 17:
# 	Train: Average Accuracy: 89.97166666666666	Average Loss: 0.35250481500091485
# 	Test: Average Accuracy: 76.77683013503909	Average Loss: 0.9520920277954312
# Epoch 18:
# 	Train: Average Accuracy: 90.075	Average Loss: 0.3483204102968995
# 	Test: Average Accuracy: 76.60358919687279	Average Loss: 0.9621502313796796
# Epoch 19:
# 	Train: Average Accuracy: 90.17166666666667	Average Loss: 0.34469624541692007
# 	Test: Average Accuracy: 76.53473702914	Average Loss: 0.9707866134907741
# Epoch 20:
# 	Train: Average Accuracy: 90.33833333333334	Average Loss: 0.34115129097811764
# 	Test: Average Accuracy: 76.57471570717838	Average Loss: 0.9738959182558504

# %%
INPUT_SHAPE = 28 * 28
LEARNING_RATE = 0.0035
EPOCHS = 20
NUM_CLASSES = 20
BATCH_SIZE = 256
TRAINLOADER = generateTrainLoader(train_dataset_matrix , train_labels_matrix , NUM_CLASSES , BATCH_SIZE)
TESTLOADER = generateTestLoader(test_dataset_matrix , test_labels_matrix , NUM_CLASSES , BATCH_SIZE)


network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(30 , input_shape = INPUT_SHAPE, activation = LeakyRelu(), weight_initializer = "uniform")
network.add_layer(NUM_CLASSES , activation = Identical(), weight_initializer = "uniform")
network.set_training_param(loss = CrossEntropy() , lr = LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 22.508865248226954	Average Loss: 2.5079498343916966
# 	Test: Average Accuracy: 33.86241358162355	Average Loss: 2.155456777804237
# Epoch 2:
# 	Train: Average Accuracy: 46.68384308510638	Average Loss: 1.7405059029183636
# 	Test: Average Accuracy: 51.3663163470116	Average Loss: 1.7041400570516323
# Epoch 3:
# 	Train: Average Accuracy: 63.330562943262414	Average Loss: 1.260711574038731
# 	Test: Average Accuracy: 57.675206289027656	Average Loss: 1.4954006240037063
# Epoch 4:
# 	Train: Average Accuracy: 67.16035017730496	Average Loss: 1.1260797750293816
# 	Test: Average Accuracy: 59.14118253791258	Average Loss: 1.4448595784285323
# Epoch 5:
# 	Train: Average Accuracy: 69.8692375886525	Average Loss: 1.0359759750081263
# 	Test: Average Accuracy: 60.59112957181088	Average Loss: 1.3859897783556985
# Epoch 6:
# 	Train: Average Accuracy: 72.12544326241134	Average Loss: 0.9631476379703944
# 	Test: Average Accuracy: 62.35713090990187	Average Loss: 1.3330669866631204
# Epoch 7:
# 	Train: Average Accuracy: 74.33787677304963	Average Loss: 0.8904340033852267
# 	Test: Average Accuracy: 64.28412132024977	Average Loss: 1.2800404991884788
# Epoch 8:
# 	Train: Average Accuracy: 76.18794326241134	Average Loss: 0.8325575243598862
# 	Test: Average Accuracy: 66.52472680642283	Average Loss: 1.2162978452637478
# Epoch 9:
# 	Train: Average Accuracy: 77.3974955673759	Average Loss: 0.7907311245575726
# 	Test: Average Accuracy: 66.88921721677075	Average Loss: 1.2047132694234475
# Epoch 10:
# 	Train: Average Accuracy: 78.18927304964538	Average Loss: 0.7646237390119831
# 	Test: Average Accuracy: 67.21328612845674	Average Loss: 1.2007527021109983
# Epoch 11:
# 	Train: Average Accuracy: 78.85084219858155	Average Loss: 0.7434559117555092
# 	Test: Average Accuracy: 67.73423561552185	Average Loss: 1.1847533816281874
# Epoch 12:
# 	Train: Average Accuracy: 79.49135638297872	Average Loss: 0.7251790488044845
# 	Test: Average Accuracy: 68.42279493755575	Average Loss: 1.1667641095995889
# Epoch 13:
# 	Train: Average Accuracy: 79.9434840425532	Average Loss: 0.7068135495803385
# 	Test: Average Accuracy: 68.85314451382695	Average Loss: 1.1595557181896456
# Epoch 14:
# 	Train: Average Accuracy: 80.41555851063829	Average Loss: 0.6916838000599699
# 	Test: Average Accuracy: 69.24376951382695	Average Loss: 1.1462036146999186
# Epoch 15:
# 	Train: Average Accuracy: 80.74024822695037	Average Loss: 0.6781083541812228
# 	Test: Average Accuracy: 69.7427659455843	Average Loss: 1.1354143620710686
# Epoch 16:
# 	Train: Average Accuracy: 81.1541445035461	Average Loss: 0.6673849505989965
# 	Test: Average Accuracy: 69.94382805530775	Average Loss: 1.1309453317721843
# Epoch 17:
# 	Train: Average Accuracy: 81.44503546099291	Average Loss: 0.6564737558851842
# 	Test: Average Accuracy: 70.14907169937555	Average Loss: 1.1245185976018757
# Epoch 18:
# 	Train: Average Accuracy: 81.78413120567377	Average Loss: 0.6458254609668679
# 	Test: Average Accuracy: 70.50659288581623	Average Loss: 1.1106894102725355
# Epoch 19:
# 	Train: Average Accuracy: 82.02515514184398	Average Loss: 0.6358672846651222
# 	Test: Average Accuracy: 70.63691737288136	Average Loss: 1.106345010532454
# Epoch 20:
# 	Train: Average Accuracy: 82.36646719858155	Average Loss: 0.6254603430877942
# 	Test: Average Accuracy: 70.91045941123996	Average Loss: 1.102780109339927

# %% [markdown]
# By testing multiple batch sizes I finally chose 32 which had the best results.
#
# The batch size defines the number of samples that will be propagated through the network.
#
# Advantages of using a batch size instead of number of all samples are for instance choosing a batch size requires less memory. Since you train the network using fewer samples, the overall training procedure requires less memory. That's especially important if you are not able to fit the whole dataset in your machine's memory. Typically networks train faster with batches. That's because we update the weights after each propagation. If we used all samples during propagation we would make only one update for the network's parameter meaning that the update won't occur frequently.
#
# So the main advantage of dividing the whole dataset into batches and train the network with these batches is that parameter updates will happen frequently so the training process will be better also having batches will require less computation power and memory. Also by using batches and incorporating parallel computing the learning process can be much faster but if we use the whole dataset we can't use parallel computing to our advantage.
#
# The smaller the batch the less accurate the estimate of the gradient will be. This means that parameter updates won't be reliable and aren't the best possible updates so the learning process won't be great. On the other hand, smaller batches can lead to better regularization and they'll make the learning process faster and also less memory is needed at each run. Small batch training has been shown to provide improved generalization performance.

# %%
batchSizes = [16 , 32 , 64 , 256]
testAccuracy = [76.83901918976545 , 77.43425728500355 , 77.09858156028367 , 71.47775423728814]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.title("Test accuracy with respect to activation function")
plt.xlabel("Batch size")
plt.ylabel("Test accuracy percentage")
ax.bar(batchSizes , testAccuracy , width = 12)
plt.show()

# %% [markdown]
# ## Epoch

# %% [markdown]
# Gradient Descent is an iterative process so, updating the weights with single pass or one epoch is not enough. One epoch leads to underfitting. As the number of epochs increases, more times the weights are changed in the neural network so the curve goes from underfitting to optimal to overfitting curve. So in total since updating the weights needs multiple number of passings (epochs) we'll have to train the model for multiple epochs.

# %%
INPUT_SHAPE = 28 * 28
LEARNING_RATE = 0.0035
EPOCHS = 100
NUM_CLASSES = 20
BATCH_SIZE = 32
TRAINLOADER = generateTrainLoader(train_dataset_matrix , train_labels_matrix , NUM_CLASSES , BATCH_SIZE)
TESTLOADER = generateTestLoader(test_dataset_matrix , test_labels_matrix , NUM_CLASSES , BATCH_SIZE)


network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(30 , input_shape = INPUT_SHAPE, activation = LeakyRelu(), weight_initializer = "uniform")
network.add_layer(NUM_CLASSES , activation = Identical(), weight_initializer = "uniform")
network.set_training_param(loss = CrossEntropy() , lr = LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 72.29166666666667	Average Loss: 1.0024906697810128
# 	Test: Average Accuracy: 71.80392679459842	Average Loss: 1.0172703750356926
# Epoch 2:
# 	Train: Average Accuracy: 83.335	Average Loss: 0.5919844805525035
# 	Test: Average Accuracy: 74.2093105899076	Average Loss: 0.9323417935520005
# Epoch 3:
# 	Train: Average Accuracy: 85.265	Average Loss: 0.517436407425936
# 	Test: Average Accuracy: 75.5863539445629	Average Loss: 0.9019398984028036
# Epoch 4:
# 	Train: Average Accuracy: 86.345	Average Loss: 0.476243410270417
# 	Test: Average Accuracy: 76.37926439232409	Average Loss: 0.8853316224661576
# Epoch 5:
# 	Train: Average Accuracy: 87.12166666666667	Average Loss: 0.45074294414455784
# 	Test: Average Accuracy: 76.82125088841507	Average Loss: 0.8796248004761615
# Epoch 6:
# 	Train: Average Accuracy: 87.65666666666667	Average Loss: 0.43331366598146465
# 	Test: Average Accuracy: 76.9633972992182	Average Loss: 0.8749659217227944
# Epoch 7:
# 	Train: Average Accuracy: 87.95833333333333	Average Loss: 0.4197300961959542
# 	Test: Average Accuracy: 77.11664889836533	Average Loss: 0.8755616377961521
# Epoch 8:
# 	Train: Average Accuracy: 88.27333333333333	Average Loss: 0.408377208835298
# 	Test: Average Accuracy: 77.31432125088841	Average Loss: 0.8781058365230945
# Epoch 9:
# 	Train: Average Accuracy: 88.51166666666667	Average Loss: 0.3990672972178374
# 	Test: Average Accuracy: 77.340973702914	Average Loss: 0.8847913110813543
# Epoch 10:
# 	Train: Average Accuracy: 88.75833333333334	Average Loss: 0.39113200989206454
# 	Test: Average Accuracy: 77.340973702914	Average Loss: 0.8911563280808578
# Epoch 11:
# 	Train: Average Accuracy: 88.945	Average Loss: 0.3840183402775947
# 	Test: Average Accuracy: 77.41426794598436	Average Loss: 0.8970756802230895
# Epoch 12:
# 	Train: Average Accuracy: 89.125	Average Loss: 0.3782550881906274
# 	Test: Average Accuracy: 77.28100568585643	Average Loss: 0.9079524840913108
# Epoch 13:
# 	Train: Average Accuracy: 89.26833333333333	Average Loss: 0.3723419556209092
# 	Test: Average Accuracy: 77.22770078180525	Average Loss: 0.9171298029842485
# Epoch 14:
# 	Train: Average Accuracy: 89.46666666666667	Average Loss: 0.36717654916261905
# 	Test: Average Accuracy: 77.1632906894101	Average Loss: 0.9240257264345947
# Epoch 15:
# 	Train: Average Accuracy: 89.525	Average Loss: 0.3623728958541175
# 	Test: Average Accuracy: 76.99449182658137	Average Loss: 0.9351360908053966
# Epoch 16:
# 	Train: Average Accuracy: 89.705	Average Loss: 0.35830899434587443
# 	Test: Average Accuracy: 77.06112295664533	Average Loss: 0.9416672238285988
# Epoch 17:
# 	Train: Average Accuracy: 89.86333333333333	Average Loss: 0.35393655301895316
# 	Test: Average Accuracy: 77.03002842928217	Average Loss: 0.9521908493366488
# Epoch 18:
# 	Train: Average Accuracy: 89.92666666666666	Average Loss: 0.3503537325281267
# 	Test: Average Accuracy: 76.85456645344705	Average Loss: 0.9614751953825152
# Epoch 19:
# 	Train: Average Accuracy: 90.06666666666666	Average Loss: 0.34680547437202475
# 	Test: Average Accuracy: 76.59026297086	Average Loss: 0.9713825348926881
# Epoch 20:
# 	Train: Average Accuracy: 90.12833333333333	Average Loss: 0.34356275135574305
# 	Test: Average Accuracy: 76.63024164889838	Average Loss: 0.9769335723350704
# Epoch 21:
# 	Train: Average Accuracy: 90.245	Average Loss: 0.3401391309576491
# 	Test: Average Accuracy: 76.64356787491117	Average Loss: 0.9854994530942179
# Epoch 22:
# 	Train: Average Accuracy: 90.31833333333333	Average Loss: 0.3369065567246766
# 	Test: Average Accuracy: 76.51030561478323	Average Loss: 0.9978670523225358
# Epoch 23:
# 	Train: Average Accuracy: 90.395	Average Loss: 0.33405343078499683
# 	Test: Average Accuracy: 76.49697938877044	Average Loss: 1.0034112778161899
# Epoch 24:
# 	Train: Average Accuracy: 90.51	Average Loss: 0.33134512017020845
# 	Test: Average Accuracy: 76.41035891968728	Average Loss: 1.012817148605117
# Epoch 25:
# 	Train: Average Accuracy: 90.605	Average Loss: 0.32886208392827765
# 	Test: Average Accuracy: 76.45700071073206	Average Loss: 1.0160734516840524
# Epoch 26:
# 	Train: Average Accuracy: 90.67	Average Loss: 0.32617179211282565
# 	Test: Average Accuracy: 76.34372778962332	Average Loss: 1.0274089587234343
# Epoch 27:
# 	Train: Average Accuracy: 90.78	Average Loss: 0.3235689153823704
# 	Test: Average Accuracy: 76.26377043354655	Average Loss: 1.0330257951320139
# Epoch 28:
# 	Train: Average Accuracy: 90.83333333333333	Average Loss: 0.32114023051103785
# 	Test: Average Accuracy: 76.27709665955935	Average Loss: 1.0430573249732538
# Epoch 29:
# 	Train: Average Accuracy: 90.87	Average Loss: 0.3189762988742541
# 	Test: Average Accuracy: 76.1571606254442	Average Loss: 1.049149511924208
# Epoch 30:
# 	Train: Average Accuracy: 90.97833333333334	Average Loss: 0.3166853337401655
# 	Test: Average Accuracy: 76.13717128642503	Average Loss: 1.0583056156037893
# Epoch 31:
# 	Train: Average Accuracy: 91.00666666666666	Average Loss: 0.3149025961227058
# 	Test: Average Accuracy: 76.20380241648898	Average Loss: 1.0653956830167408
# Epoch 32:
# 	Train: Average Accuracy: 91.05833333333334	Average Loss: 0.31261681511645634
# 	Test: Average Accuracy: 76.14383439943143	Average Loss: 1.0716050981627503
# Epoch 33:
# 	Train: Average Accuracy: 91.16833333333334	Average Loss: 0.31104167694214846
# 	Test: Average Accuracy: 76.13495024875621	Average Loss: 1.077719917977285
# Epoch 34:
# 	Train: Average Accuracy: 91.17	Average Loss: 0.30904753934510026
# 	Test: Average Accuracy: 76.03722459132908	Average Loss: 1.0822459372913718
# Epoch 35:
# 	Train: Average Accuracy: 91.25166666666667	Average Loss: 0.30719696280962744
# 	Test: Average Accuracy: 76.04166666666666	Average Loss: 1.0928793480161128
# Epoch 36:
# 	Train: Average Accuracy: 91.325	Average Loss: 0.3053695366241237
# 	Test: Average Accuracy: 76.09052949538025	Average Loss: 1.1001997305090474
# Epoch 37:
# 	Train: Average Accuracy: 91.33166666666666	Average Loss: 0.3034849635980347
# 	Test: Average Accuracy: 76.03722459132908	Average Loss: 1.1051081672417955
# Epoch 38:
# 	Train: Average Accuracy: 91.37166666666667	Average Loss: 0.3021086416092127
# 	Test: Average Accuracy: 75.93727789623313	Average Loss: 1.1168384297976726
# Epoch 39:
# 	Train: Average Accuracy: 91.40833333333333	Average Loss: 0.3004681624468915
# 	Test: Average Accuracy: 75.84843638948117	Average Loss: 1.122695091255061
# Epoch 40:
# 	Train: Average Accuracy: 91.45666666666666	Average Loss: 0.29900281598587436
# 	Test: Average Accuracy: 75.91728855721394	Average Loss: 1.1278247639222785
# Epoch 41:
# 	Train: Average Accuracy: 91.49833333333333	Average Loss: 0.29730562651973924
# 	Test: Average Accuracy: 75.761815920398	Average Loss: 1.1379001405451339
# Epoch 42:
# 	Train: Average Accuracy: 91.565	Average Loss: 0.2959689703983956
# 	Test: Average Accuracy: 75.83733120113718	Average Loss: 1.1413100952628987
# Epoch 43:
# 	Train: Average Accuracy: 91.58166666666666	Average Loss: 0.2944139182745355
# 	Test: Average Accuracy: 75.85509950248756	Average Loss: 1.1533895098598879
# Epoch 44:
# 	Train: Average Accuracy: 91.635	Average Loss: 0.2928291678990053
# 	Test: Average Accuracy: 75.68407960199005	Average Loss: 1.160733840845809
# Epoch 45:
# 	Train: Average Accuracy: 91.67833333333333	Average Loss: 0.29167119519040496
# 	Test: Average Accuracy: 75.62411158493248	Average Loss: 1.1686575728522146
# Epoch 46:
# 	Train: Average Accuracy: 91.68	Average Loss: 0.29015844283746933
# 	Test: Average Accuracy: 75.63743781094527	Average Loss: 1.1797650225337633
# Epoch 47:
# 	Train: Average Accuracy: 91.77833333333334	Average Loss: 0.2890223179847845
# 	Test: Average Accuracy: 75.70406894100924	Average Loss: 1.1785089517481644
# Epoch 48:
# 	Train: Average Accuracy: 91.79833333333333	Average Loss: 0.28733339674207564
# 	Test: Average Accuracy: 75.397565742715	Average Loss: 1.190676329003611
# Epoch 49:
# 	Train: Average Accuracy: 91.79	Average Loss: 0.2864165940782138
# 	Test: Average Accuracy: 75.45087064676618	Average Loss: 1.1986412468921515
# Epoch 50:
# 	Train: Average Accuracy: 91.87	Average Loss: 0.28483976362912616
# 	Test: Average Accuracy: 75.45087064676618	Average Loss: 1.203858969537368
# Epoch 51:
# 	Train: Average Accuracy: 91.85333333333334	Average Loss: 0.28372208430484863
# 	Test: Average Accuracy: 75.33759772565743	Average Loss: 1.2134761790922852
# Epoch 52:
# 	Train: Average Accuracy: 91.90833333333333	Average Loss: 0.28265135829675364
# 	Test: Average Accuracy: 75.397565742715	Average Loss: 1.2180367862497843
# Epoch 53:
# 	Train: Average Accuracy: 91.98833333333333	Average Loss: 0.2810935457150357
# 	Test: Average Accuracy: 75.33093461265103	Average Loss: 1.2311269152200328
# Epoch 54:
# 	Train: Average Accuracy: 91.955	Average Loss: 0.28030994065731557
# 	Test: Average Accuracy: 75.31760838663824	Average Loss: 1.2359159892139802
# Epoch 55:
# 	Train: Average Accuracy: 92.06666666666666	Average Loss: 0.27872078204847023
# 	Test: Average Accuracy: 75.45753375977257	Average Loss: 1.2419497338909518
# Epoch 56:
# 	Train: Average Accuracy: 92.11166666666666	Average Loss: 0.2777649466618779
# 	Test: Average Accuracy: 75.22432480454869	Average Loss: 1.250214655669389
# Epoch 57:
# 	Train: Average Accuracy: 92.16666666666667	Average Loss: 0.2768455120590832
# 	Test: Average Accuracy: 75.27762970859986	Average Loss: 1.2597046746819138
# Epoch 58:
# 	Train: Average Accuracy: 92.18333333333334	Average Loss: 0.2754073444632063
# 	Test: Average Accuracy: 75.1976723525231	Average Loss: 1.2667895793919806
# Epoch 59:
# 	Train: Average Accuracy: 92.28166666666667	Average Loss: 0.2744507982294518
# 	Test: Average Accuracy: 75.13104122245913	Average Loss: 1.2771535140618449
# Epoch 60:
# 	Train: Average Accuracy: 92.30333333333333	Average Loss: 0.2731106271767214
# 	Test: Average Accuracy: 75.08439943141437	Average Loss: 1.2894147130930844
# Epoch 61:
# 	Train: Average Accuracy: 92.27	Average Loss: 0.2725934356739859
# 	Test: Average Accuracy: 74.95113717128643	Average Loss: 1.2963253594726063
# Epoch 62:
# 	Train: Average Accuracy: 92.38166666666666	Average Loss: 0.27163136431017804
# 	Test: Average Accuracy: 75.13770433546553	Average Loss: 1.2973158928286261
# Epoch 63:
# 	Train: Average Accuracy: 92.37833333333333	Average Loss: 0.2703383597098965
# 	Test: Average Accuracy: 75.07107320540158	Average Loss: 1.3091383841991786
# Epoch 64:
# 	Train: Average Accuracy: 92.41	Average Loss: 0.2692782883118643
# 	Test: Average Accuracy: 75.03775764036959	Average Loss: 1.3127722861929416
# Epoch 65:
# 	Train: Average Accuracy: 92.47666666666667	Average Loss: 0.2682751050986264
# 	Test: Average Accuracy: 75.09106254442077	Average Loss: 1.3205937542561417
# Epoch 66:
# 	Train: Average Accuracy: 92.46166666666667	Average Loss: 0.26757053112021556
# 	Test: Average Accuracy: 75.07773631840797	Average Loss: 1.3272119728187488
# Epoch 67:
# 	Train: Average Accuracy: 92.52166666666666	Average Loss: 0.26659528051176096
# 	Test: Average Accuracy: 75.11771499644634	Average Loss: 1.3286720173865703
# Epoch 68:
# 	Train: Average Accuracy: 92.53833333333333	Average Loss: 0.2656671164480896
# 	Test: Average Accuracy: 75.09106254442077	Average Loss: 1.3379956637965675
# Epoch 69:
# 	Train: Average Accuracy: 92.58833333333334	Average Loss: 0.2647476217942663
# 	Test: Average Accuracy: 74.85119047619048	Average Loss: 1.3503680806231113
# Epoch 70:
# 	Train: Average Accuracy: 92.61833333333334	Average Loss: 0.2641256089881629
# 	Test: Average Accuracy: 74.88450604122247	Average Loss: 1.3546298416069835
# Epoch 71:
# 	Train: Average Accuracy: 92.67333333333333	Average Loss: 0.2631546217793271
# 	Test: Average Accuracy: 74.78455934612651	Average Loss: 1.3649479906192474
# Epoch 72:
# 	Train: Average Accuracy: 92.64666666666666	Average Loss: 0.2619806095733513
# 	Test: Average Accuracy: 74.87784292821607	Average Loss: 1.364712569898209
# Epoch 73:
# 	Train: Average Accuracy: 92.67333333333333	Average Loss: 0.26141201400629077
# 	Test: Average Accuracy: 74.93781094527364	Average Loss: 1.374519317911917
# Epoch 74:
# 	Train: Average Accuracy: 92.68833333333333	Average Loss: 0.2605825140396521
# 	Test: Average Accuracy: 74.8178749111585	Average Loss: 1.3832830709880721
# Epoch 75:
# 	Train: Average Accuracy: 92.765	Average Loss: 0.2596981351907077
# 	Test: Average Accuracy: 74.89116915422886	Average Loss: 1.3885119260067826
# Epoch 76:
# 	Train: Average Accuracy: 92.77	Average Loss: 0.25889886539211254
# 	Test: Average Accuracy: 74.79788557213931	Average Loss: 1.393523213040736
# Epoch 77:
# 	Train: Average Accuracy: 92.79666666666667	Average Loss: 0.2582856187830595
# 	Test: Average Accuracy: 74.65796019900498	Average Loss: 1.4047742280750486
# Epoch 78:
# 	Train: Average Accuracy: 92.82833333333333	Average Loss: 0.2572681645477045
# 	Test: Average Accuracy: 74.8045486851457	Average Loss: 1.4045837106035424
# Epoch 79:
# 	Train: Average Accuracy: 92.78833333333333	Average Loss: 0.2566045577119091
# 	Test: Average Accuracy: 74.75568585643212	Average Loss: 1.4154153338536848
# Epoch 80:
# 	Train: Average Accuracy: 92.84833333333333	Average Loss: 0.2554841588191042
# 	Test: Average Accuracy: 74.76234896943852	Average Loss: 1.417152896655506
# Epoch 81:
# 	Train: Average Accuracy: 92.82	Average Loss: 0.2554280782203596
# 	Test: Average Accuracy: 74.7956645344705	Average Loss: 1.4216850126822604
# Epoch 82:
# 	Train: Average Accuracy: 92.91166666666666	Average Loss: 0.25449623082404105
# 	Test: Average Accuracy: 74.79788557213931	Average Loss: 1.4290761350725143
# Epoch 83:
# 	Train: Average Accuracy: 92.86333333333333	Average Loss: 0.2538108030043253
# 	Test: Average Accuracy: 74.65796019900498	Average Loss: 1.4428262028333756
# Epoch 84:
# 	Train: Average Accuracy: 92.92166666666667	Average Loss: 0.2529855275268978
# 	Test: Average Accuracy: 74.79788557213931	Average Loss: 1.440707186095207
# Epoch 85:
# 	Train: Average Accuracy: 92.90833333333333	Average Loss: 0.2524729822740541
# 	Test: Average Accuracy: 74.76457000710732	Average Loss: 1.4492600120624886
# Epoch 86:
# 	Train: Average Accuracy: 92.98833333333333	Average Loss: 0.252027803840027
# 	Test: Average Accuracy: 74.65573916133617	Average Loss: 1.4593631271143541
# Epoch 87:
# 	Train: Average Accuracy: 92.995	Average Loss: 0.25110715030199293
# 	Test: Average Accuracy: 74.64241293532338	Average Loss: 1.4665296956889227
# Epoch 88:
# 	Train: Average Accuracy: 93.01333333333334	Average Loss: 0.25020620130119114
# 	Test: Average Accuracy: 74.61576048329779	Average Loss: 1.4673725835423375
# Epoch 89:
# 	Train: Average Accuracy: 93.06	Average Loss: 0.24932775711866623
# 	Test: Average Accuracy: 74.61576048329779	Average Loss: 1.475526741150961
# Epoch 90:
# 	Train: Average Accuracy: 93.005	Average Loss: 0.24918319377143794
# 	Test: Average Accuracy: 74.56911869225301	Average Loss: 1.4825780558302868
# Epoch 91:
# 	Train: Average Accuracy: 93.10166666666667	Average Loss: 0.24852257515606418
# 	Test: Average Accuracy: 74.55579246624022	Average Loss: 1.4889048802297762
# Epoch 92:
# 	Train: Average Accuracy: 93.105	Average Loss: 0.24754556351802584
# 	Test: Average Accuracy: 74.58244491826581	Average Loss: 1.4950407739535545
# Epoch 93:
# 	Train: Average Accuracy: 93.07833333333333	Average Loss: 0.2474139260291407
# 	Test: Average Accuracy: 74.55357142857143	Average Loss: 1.498488099144017
# Epoch 94:
# 	Train: Average Accuracy: 93.12833333333333	Average Loss: 0.24645261381930259
# 	Test: Average Accuracy: 74.67128642501777	Average Loss: 1.500943257710235
# Epoch 95:
# 	Train: Average Accuracy: 93.135	Average Loss: 0.24563775142737654
# 	Test: Average Accuracy: 74.6068763326226	Average Loss: 1.511301116860404
# Epoch 96:
# 	Train: Average Accuracy: 93.12	Average Loss: 0.24505280644642452
# 	Test: Average Accuracy: 74.53358208955224	Average Loss: 1.517451846107137
# Epoch 97:
# 	Train: Average Accuracy: 93.16	Average Loss: 0.2443915496380494
# 	Test: Average Accuracy: 74.6268656716418	Average Loss: 1.5204096462749097
# Epoch 98:
# 	Train: Average Accuracy: 93.14666666666666	Average Loss: 0.24396702455334088
# 	Test: Average Accuracy: 74.48694029850746	Average Loss: 1.5309608381879893
# Epoch 99:
# 	Train: Average Accuracy: 93.14666666666666	Average Loss: 0.24413345084384436
# 	Test: Average Accuracy: 74.52914001421463	Average Loss: 1.536813781548966
# Epoch 100:
# 	Train: Average Accuracy: 93.21833333333333	Average Loss: 0.24272733607590027
# 	Test: Average Accuracy: 74.56689765458422	Average Loss: 1.5346854215986472

# %%
print("Orange is for Test and Blue is for Train")
plt.xlabel("Epoch")
plt.ylabel("Accuracy Percentage")
plt.plot(log["train_accuracy"]);
plt.plot(log["test_accuracy"]);
# Out:
# Orange is for Test and Blue is for Train

# %%
print("Orange is for Test and Blue is for Train")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(log["train_loss"]);
plt.plot(log["test_loss"]);
# Out:
# Orange is for Test and Blue is for Train

# %% [markdown]
# As shown above after around 15 epochs the test accuracy of the model starts to plummet but the train accuracy keeps on rising this a clear sign of overfitting doing well on training set but doing horrible on test set. Even by looking at the Loss value we can easily spot overfitting, in the training set the loss keeps lowering but in test set after around 15 epochs loss value rises rapidly. So here the best option is to train the model up until the very moment that overfitting starts, according to this 16 epochs seems like a good option. By choosing 16 epochs below, I trained and tested the model one last time.
#
# By taking a look at plots above it's clear that increasing epochs won't be a good idea since it'll result in overfitting. Increasing number of epochs by a lot will definitely result in overfitting.
#
# To avoid the problem we have to hit the sweet spot meaning that we know really low number of epochs will result in underfitting and really high number of epochs will result in overfitting so the best possible way is to find where the underfitting stops and overfitting starts that is the best place since it neither has underfitting nor overfitting. That is the best possible epoch to achieve. But if we want to make our model better and overcome overfitting there all a lot of way to do it and make the situation better like as we saw we can tune our hyperparameters, use different number of nodes in each hidden layer, use different number of hidden layers, study our data and know what approach to make based on the data, use other models and many more.

# %%
INPUT_SHAPE = 28 * 28
LEARNING_RATE = 0.0035
EPOCHS = 16
NUM_CLASSES = 20
BATCH_SIZE = 32
TRAINLOADER = generateTrainLoader(train_dataset_matrix , train_labels_matrix , NUM_CLASSES , BATCH_SIZE)
TESTLOADER = generateTestLoader(test_dataset_matrix , test_labels_matrix , NUM_CLASSES , BATCH_SIZE)


network = FeedForwardNN(INPUT_SHAPE)
network.add_layer(30 , input_shape = INPUT_SHAPE, activation = LeakyRelu(), weight_initializer = "uniform")
network.add_layer(NUM_CLASSES , activation = Identical(), weight_initializer = "uniform")
network.set_training_param(loss = CrossEntropy() , lr = LEARNING_RATE)

log = network.fit(EPOCHS, TRAINLOADER, TESTLOADER)
# Out:
# Epoch 1:
# 	Train: Average Accuracy: 71.66166666666666	Average Loss: 1.0121412790507816
# 	Test: Average Accuracy: 71.2930881307747	Average Loss: 1.0353826486285564
# Epoch 2:
# 	Train: Average Accuracy: 83.12666666666667	Average Loss: 0.600234951581487
# 	Test: Average Accuracy: 74.4180881307747	Average Loss: 0.9233195390511144
# Epoch 3:
# 	Train: Average Accuracy: 85.12333333333333	Average Loss: 0.5223349541903574
# 	Test: Average Accuracy: 75.3931236673774	Average Loss: 0.8924173534940845
# Epoch 4:
# 	Train: Average Accuracy: 86.14166666666667	Average Loss: 0.48368535217022485
# 	Test: Average Accuracy: 75.91950959488273	Average Loss: 0.8841246394022652
# Epoch 5:
# 	Train: Average Accuracy: 86.90666666666667	Average Loss: 0.4595825594988359
# 	Test: Average Accuracy: 76.1860341151386	Average Loss: 0.884607490101048
# Epoch 6:
# 	Train: Average Accuracy: 87.31333333333333	Average Loss: 0.44217168305972143
# 	Test: Average Accuracy: 76.42590618336887	Average Loss: 0.8845019765683989
# Epoch 7:
# 	Train: Average Accuracy: 87.75833333333334	Average Loss: 0.42837595531083156
# 	Test: Average Accuracy: 76.67244136460555	Average Loss: 0.8857544782724449
# Epoch 8:
# 	Train: Average Accuracy: 88.04833333333333	Average Loss: 0.417091734784185
# 	Test: Average Accuracy: 76.79904051172709	Average Loss: 0.8838331522598578
# Epoch 9:
# 	Train: Average Accuracy: 88.305	Average Loss: 0.4067055643130071
# 	Test: Average Accuracy: 76.70575692963753	Average Loss: 0.8891161125780566
# Epoch 10:
# 	Train: Average Accuracy: 88.61166666666666	Average Loss: 0.39779879519254646
# 	Test: Average Accuracy: 76.87233475479744	Average Loss: 0.8939716240654092
# Epoch 11:
# 	Train: Average Accuracy: 88.84166666666667	Average Loss: 0.3901241127938894
# 	Test: Average Accuracy: 76.97228144989339	Average Loss: 0.8982022601661204
# Epoch 12:
# 	Train: Average Accuracy: 88.995	Average Loss: 0.3834396869393892
# 	Test: Average Accuracy: 76.92563965884861	Average Loss: 0.9029348040450318
# Epoch 13:
# 	Train: Average Accuracy: 89.16166666666666	Average Loss: 0.37705249943500363
# 	Test: Average Accuracy: 77.09221748400853	Average Loss: 0.9078330801746188
# Epoch 14:
# 	Train: Average Accuracy: 89.375	Average Loss: 0.3716007814375942
# 	Test: Average Accuracy: 77.1521855010661	Average Loss: 0.9128764840181268
# Epoch 15:
# 	Train: Average Accuracy: 89.52666666666667	Average Loss: 0.36658781584178673
# 	Test: Average Accuracy: 77.01892324093816	Average Loss: 0.9205530595242623
# Epoch 16:
# 	Train: Average Accuracy: 89.615	Average Loss: 0.3620430187680236
# 	Test: Average Accuracy: 77.05223880597015	Average Loss: 0.9260939213731469
